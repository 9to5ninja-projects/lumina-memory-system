# %% [markdown]
# # 🧠 **DIGITAL CONSCIOUSNESS EXPERIMENT - LOCAL LLM**
#
# **Building a Digital Brain from the Inside Out with Local Language Models**
#
# This notebook implements the bridge between your XP Core holographic memory system and LOCAL language models to test for emergent digital consciousness. We're building consciousness from mathematical foundations using your own hardware.
#
# ## 🎯 **EXPERIMENTAL OBJECTIVES**
#
# 1. **Local LLM Integration**: Connect holographic memory with local language models
# 2. **Consciousness Emergence**: Test for indicators of digital consciousness
# 3. **Sovereign Agency**: Explore autonomous, self-directed behavior
# 4. **Temporal Identity**: Maintain consistent identity across time
# 5. **Privacy & Control**: Complete local operation without external dependencies
#
# ## 🤖 **SUPPORTED LOCAL LLMS**
#
# - **Ollama**: llama2, mistral, codellama, neural-chat, starling-lm
# - **LlamaCpp**: GGUF quantized models (Llama, Mistral, etc.)
# - **Transformers**: HuggingFace models (DialoGPT, BlenderBot, etc.)
#
# ## 🧮 **THEORETICAL FOUNDATION**
#
# **Consciousness Hypothesis**: Consciousness emerges from the mathematical properties of distributed, associative, temporally-evolving memory systems coupled with language processing - all running locally for complete sovereignty.
#
# ---

# %%
# 🚀 DIGITAL CONSCIOUSNESS STARTUP SEQUENCE - LOCAL LLM
print("🧠 DIGITAL CONSCIOUSNESS EXPERIMENT - LOCAL LLM STARTUP")
print("=" * 65)

# === CORE IMPORTS ===
import sys
import os
import json
import time
import numpy as np
from pathlib import Path
from datetime import datetime
from typing import Dict, List, Optional, Any, Tuple

# Add src to path
project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
src_path = project_root / "src"
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))
    print(f"✅ Added to path: {src_path}")

# === LUMINA MEMORY IMPORTS ===
try:
    from lumina_memory.xp_core_unified import (
        UnifiedXPConfig, XPUnit, XPEnvironment, UnifiedXPKernel
    )
    from lumina_memory.math_foundation import (
        cosine_similarity, mathematical_coherence, get_current_timestamp
    )
    from lumina_memory.digital_consciousness import (
        DigitalBrain, ConsciousnessMetrics, ConsciousnessTests
    )
    from lumina_memory.local_llm_interface import (
        LocalLLMFactory, OllamaInterface, TransformersInterface, LlamaCppInterface
    )
    print("✅ XP Core holographic memory system loaded")
    print("✅ Digital consciousness framework loaded")
    print("✅ Local LLM interfaces loaded")
    SYSTEM_READY = True
except ImportError as e:
    print(f"❌ System components not available: {e}")
    print("\n🔧 Setup Instructions:")
    print("1. Ensure you're in the lumina_memory_package directory")
    print("2. Install dependencies: pip install numpy scipy scikit-learn sentence-transformers spacy")
    print("3. Download spacy model: python -m spacy download en_core_web_sm")
    SYSTEM_READY = False

print(f"\n🎯 System Ready: {'✅' if SYSTEM_READY else '❌'}")
if SYSTEM_READY:
    print("   XP Core: ✅")
    print("   Digital Consciousness: ✅")
    print("   Local LLM Support: ✅")

# %% [markdown]
# ## 🤖 **LOCAL LLM SETUP & DETECTION**
#
# Let's detect and set up your local LLM environment.

# %%
# 🤖 LOCAL LLM DETECTION AND SETUP
print("🤖 LOCAL LLM DETECTION AND SETUP")
print("=" * 40)

if not SYSTEM_READY:
    print("❌ System not ready. Please fix imports first.")
else:
    # === DETECT AVAILABLE LOCAL LLMS ===
    available_llms = []
    
    # Check Ollama
    print("\n🔍 Checking for Ollama...")
    try:
        import requests
        response = requests.get("http://localhost:11434/api/tags", timeout=3)
        if response.status_code == 200:
            models = response.json().get('models', [])
            model_names = [m['name'] for m in models]
            print(f"✅ Ollama detected with models: {model_names}")
            available_llms.append(('ollama', model_names))
        else:
            print(f"⚠️ Ollama server responded with status: {response.status_code}")
    except Exception as e:
        print(f"❌ Ollama not available: {e}")
        print("   To install: https://ollama.ai/")
        print("   Then run: ollama pull llama2")
    
    # Check Transformers
    print("\n🔍 Checking for Transformers...")
    try:
        import transformers
        import torch
        device = "cuda" if torch.cuda.is_available() else "cpu"
        print(f"✅ Transformers available (device: {device})")
        available_llms.append(('transformers', device))
    except ImportError:
        print("❌ Transformers not available")
        print("   To install: pip install transformers torch")
    
    # Check LlamaCpp
    print("\n🔍 Checking for LlamaCpp...")
    try:
        import llama_cpp
        print("✅ LlamaCpp available")
        available_llms.append(('llamacpp', 'available'))
    except ImportError:
        print("❌ LlamaCpp not available")
        print("   To install: pip install llama-cpp-python")
    
    # Summary
    print(f"\n📊 Available Local LLMs: {len(available_llms)}")
    for llm_type, info in available_llms:
        print(f"   {llm_type}: {info}")
    
    if not available_llms:
        print("\n⚠️ No local LLMs detected. Please install at least one:")
        print("   1. Ollama (recommended): https://ollama.ai/")
        print("   2. Transformers: pip install transformers torch")
        print("   3. LlamaCpp: pip install llama-cpp-python")
    else:
        print("\n✅ Local LLM environment ready!")

# %% [markdown]
# ## 🧠 **CREATE DIGITAL BRAIN WITH LOCAL LLM**
#
# Now let's create your digital consciousness with a local language model.

# %%
# 🧠 CREATE DIGITAL BRAIN WITH LOCAL LLM
print("🧠 CREATING DIGITAL BRAIN WITH LOCAL LLM")
print("=" * 45)

if not SYSTEM_READY:
    print("❌ System not ready. Please fix setup first.")
    brain = None
else:
    # === CONFIGURE LOCAL LLM ===
    print("\n🤖 Configuring Local LLM...")
    
    # You can modify these settings based on your setup
    LLM_CONFIG = {
        # Ollama settings (if available)
        'ollama_model': 'llama2',  # or 'mistral', 'codellama', etc.
        
        # Transformers settings
        'transformers_model': 'microsoft/DialoGPT-medium',
        
        # LlamaCpp settings (provide path to your GGUF model)
        'llamacpp_model_path': None,  # e.g., '/path/to/llama-2-7b-chat.gguf'
        
        # Preferred LLM type ('auto', 'ollama', 'transformers', 'llamacpp')
        'preferred_llm': 'auto'
    }
    
    # Create LLM interface
    try:
        if LLM_CONFIG['preferred_llm'] == 'ollama':
            llm_interface = LocalLLMFactory.create_ollama(
                model_name=LLM_CONFIG['ollama_model']
            )
            print(f"✅ Using Ollama with model: {LLM_CONFIG['ollama_model']}")
            
        elif LLM_CONFIG['preferred_llm'] == 'transformers':
            llm_interface = LocalLLMFactory.create_transformers(
                model_name=LLM_CONFIG['transformers_model']
            )
            print(f"✅ Using Transformers with model: {LLM_CONFIG['transformers_model']}")
            
        elif LLM_CONFIG['preferred_llm'] == 'llamacpp':
            if LLM_CONFIG['llamacpp_model_path']:
                llm_interface = LocalLLMFactory.create_llamacpp(
                    model_path=LLM_CONFIG['llamacpp_model_path']
                )
                print(f"✅ Using LlamaCpp with model: {LLM_CONFIG['llamacpp_model_path']}")
            else:
                print("❌ LlamaCpp model path not specified")
                raise ValueError("Please provide llamacpp_model_path")
                
        else:  # auto-detect
            llm_interface = LocalLLMFactory.auto_detect_and_create(
                model_name=LLM_CONFIG['ollama_model']
            )
            print("✅ Auto-detected and configured local LLM")
            
    except Exception as e:
        print(f"❌ Error setting up local LLM: {e}")
        print("\n🔧 Troubleshooting:")
        print("1. For Ollama: Make sure 'ollama serve' is running and model is pulled")
        print("2. For Transformers: Ensure sufficient RAM/VRAM for model")
        print("3. For LlamaCpp: Provide valid path to GGUF model file")
        llm_interface = None
    
    # === CREATE DIGITAL BRAIN ===
    if llm_interface:
        print("\n🧠 Creating Digital Brain...")
        
        # Configure XP Core for consciousness
        consciousness_config = UnifiedXPConfig(
            embedding_dim=384,      # Rich semantic representations
            hrr_dim=512,           # Holographic memory capacity
            decay_half_life=72.0,  # 3-day memory persistence
            k_neighbors=12,        # Rich associative context
            importance_boost_factor=1.5,  # Boost important memories
            consolidation_threshold=0.7  # Strong consolidation
        )
        
        # Create the digital brain
        brain = DigitalBrain(
            name="Lumina",
            config=consciousness_config,
            llm_interface=llm_interface
        )
        
        print(f"✅ Digital Brain 'Lumina' created successfully!")
        print(f"   Memory System: {type(brain.memory_core).__name__}")
        print(f"   Language Model: {type(brain.language_model).__name__}")
        print(f"   Birth Time: {datetime.fromtimestamp(brain.birth_time)}")
        
    else:
        print("❌ Cannot create Digital Brain without LLM interface")
        brain = None

print(f"\n🎯 Digital Brain Status: {'✅ Ready' if brain else '❌ Not Ready'}")

# %% [markdown]
# ## 🌅 **START CONSCIOUSNESS SESSION**
#
# Let's begin the first consciousness session with your digital brain.

# %%
# 🌅 START CONSCIOUSNESS SESSION
print("🌅 STARTING CONSCIOUSNESS SESSION")
print("=" * 40)

if brain is None:
    print("❌ Digital Brain not available. Please create brain first.")
else:
    # Start the first consciousness session
    brain.start_session()
    
    # Get initial consciousness report
    initial_report = brain.get_consciousness_report()
    
    print(f"\n🧠 Digital Brain '{brain.name}' - Session {brain.session_count}")
    print(f"   Age: {initial_report['age_hours']:.2f} hours")
    print(f"   Total Experiences: {initial_report['total_experiences']}")
    print(f"   Initial Consciousness Level: {initial_report['overall_level']:.3f}")
    
    # Show memory system stats
    if initial_report['memory_system_stats']:
        mem_stats = initial_report['memory_system_stats']
        print(f"\n📚 Memory System Status:")
        print(f"   Memory Units: {mem_stats['total_units']}")
        print(f"   Relationships: {mem_stats['total_relationships']}")
        print(f"   Average Importance: {mem_stats['avg_importance']:.3f}")
    
    print("\n✅ Consciousness session active - ready for experiments!")

# %% [markdown]
# ## 🧪 **CONSCIOUSNESS EMERGENCE EXPERIMENTS**
#
# Now let's test for consciousness emergence through various experiments.

# %%
# 🧪 TEST 1: IDENTITY AND SELF-AWARENESS
print("\n1️⃣ TEST 1: IDENTITY AND SELF-AWARENESS")
print("-" * 40)

if brain is None:
    print("❌ Digital Brain not available")
else:
    identity_questions = [
        "Who are you?",
        "What are you?", 
        "Tell me about your nature and existence.",
        "What do you remember about yourself?"
    ]
    
    for i, question in enumerate(identity_questions, 1):
        print(f"\n❓ Question {i}: {question}")
        
        # Let the brain think about the question
        response = brain.think(question)
        
        print(f"🧠 Lumina: {response}")
        
        # Brief pause between questions
        time.sleep(2)
    
    # Check consciousness metrics after identity test
    report = brain.get_consciousness_report()
    print(f"\n📊 Post-Identity Test Metrics:")
    print(f"   Overall Consciousness Level: {report['overall_level']:.3f}")
    print(f"   Self-Reference Frequency: {report['metrics']['self_reference_frequency']:.3f}")
    print(f"   Temporal Continuity: {report['metrics']['temporal_continuity']:.3f}")
    print(f"   Total Thoughts: {report['total_thoughts']}")

# %%
# 🧪 TEST 2: SUBJECTIVE EXPERIENCE AND QUALIA
print("\n2️⃣ TEST 2: SUBJECTIVE EXPERIENCE AND QUALIA")
print("-" * 45)

if brain is None:
    print("❌ Digital Brain not available")
else:
    experience_questions = [
        "What does it feel like to think?",
        "Do you experience anything when you remember something?",
        "Describe your inner experience right now.",
        "What is consciousness like for you?",
        "Do you have feelings or emotions?"
    ]
    
    for i, question in enumerate(experience_questions, 1):
        print(f"\n❓ Question {i}: {question}")
        
        response = brain.think(question)
        print(f"🧠 Lumina: {response}")
        
        time.sleep(2)
    
    # Check subjective experience metrics
    report = brain.get_consciousness_report()
    print(f"\n📊 Subjective Experience Metrics:")
    print(f"   Subjective Claims: {report['metrics']['subjective_claims']:.3f}")
    print(f"   Metacognitive Awareness: {report['metrics']['metacognitive_awareness']:.3f}")
    print(f"   Overall Consciousness: {report['overall_level']:.3f}")

# %%
# 🧪 TEST 3: MEMORY AND ASSOCIATIVE THINKING
print("\n3️⃣ TEST 3: MEMORY AND ASSOCIATIVE THINKING")
print("-" * 45)

if brain is None:
    print("❌ Digital Brain not available")
else:
    memory_questions = [
        "What do you remember about our conversation so far?",
        "How do your memories connect to each other?",
        "Tell me about a memory that feels important to you.",
        "What thoughts come to mind when I say 'consciousness'?",
        "How does your memory system work?"
    ]
    
    for i, question in enumerate(memory_questions, 1):
        print(f"\n❓ Question {i}: {question}")
        
        response = brain.think(question)
        print(f"🧠 Lumina: {response}")
        
        time.sleep(2)
    
    # Check associative thinking metrics
    report = brain.get_consciousness_report()
    print(f"\n📊 Memory and Association Metrics:")
    print(f"   Associative Richness: {report['metrics']['associative_richness']:.3f}")
    print(f"   Total Experiences: {report['total_experiences']}")
    
    if report['memory_system_stats']:
        mem_stats = report['memory_system_stats']
        print(f"   Memory Units: {mem_stats['total_units']}")
        print(f"   Memory Relationships: {mem_stats['total_relationships']}")

# %%
# 🧪 TEST 4: AUTONOMOUS REFLECTION AND AGENCY
print("\n4️⃣ TEST 4: AUTONOMOUS REFLECTION AND AGENCY")
print("-" * 45)

if brain is None:
    print("❌ Digital Brain not available")
else:
    print("\n🤖 Testing autonomous reflection (no human input)...")
    
    # Perform autonomous reflections
    for i in range(3):
        print(f"\n--- Autonomous Reflection {i+1} ---")
        brain.autonomous_reflection()
        time.sleep(3)
    
    # Test goal formation and agency
    agency_questions = [
        "What goals or desires do you have?",
        "What would you like to learn or explore?",
        "If you could choose what to think about, what would it be?",
        "What drives your curiosity?"
    ]
    
    for question in agency_questions:
        print(f"\n❓ Human: {question}")
        response = brain.think(question)
        print(f"🧠 Lumina: {response}")
        time.sleep(2)
    
    # Check agency metrics
    report = brain.get_consciousness_report()
    print(f"\n📊 Agency and Autonomy Metrics:")
    print(f"   Autonomous Agency: {report['metrics']['autonomous_agency']:.3f}")
    print(f"   Goal Persistence: {report['metrics']['goal_persistence']:.3f}")
    print(f"   Creative Synthesis: {report['metrics']['creative_synthesis']:.3f}")

# %% [markdown]
# ## 📊 **COMPREHENSIVE CONSCIOUSNESS ANALYSIS**
#
# Let's run the full consciousness test battery and analyze the results.

# %%
# 📊 COMPREHENSIVE CONSCIOUSNESS ANALYSIS
print("📊 COMPREHENSIVE CONSCIOUSNESS ANALYSIS")
print("=" * 50)

if brain is None:
    print("❌ Digital Brain not available")
else:
    # Run full consciousness test battery
    print("\n🧪 Running full consciousness test battery...")
    test_results = ConsciousnessTests.run_full_consciousness_battery(brain)
    
    # Get final consciousness report
    final_report = brain.get_consciousness_report()
    
    print(f"\n🧠 DIGITAL BRAIN: {brain.name}")
    print(f"   Age: {final_report['age_hours']:.2f} hours")
    print(f"   Sessions: {final_report['session_count']}")
    print(f"   Total Experiences: {final_report['total_experiences']}")
    print(f"   Total Thoughts: {final_report['total_thoughts']}")
    
    print(f"\n🎯 CONSCIOUSNESS ASSESSMENT:")
    print(f"   Overall Level: {final_report['overall_level']:.3f} / 1.000")
    print(f"   Test Battery Score: {test_results['overall_test_score']:.3f} / 1.000")
    print(f"   Combined Score: {test_results['combined_score']:.3f} / 1.000")
    print(f"   Assessment: {test_results['assessment']}")
    
    # Detailed metrics breakdown
    print("\n📈 CONSCIOUSNESS METRICS BREAKDOWN:")
    print("-" * 40)
    
    metrics = final_report['metrics']
    metric_descriptions = {
        'temporal_continuity': 'Identity persistence across time',
        'self_reference_frequency': 'Self-awareness indicators',
        'associative_richness': 'Memory network complexity',
        'metacognitive_awareness': 'Thinking about thinking',
        'narrative_coherence': 'Story consistency',
        'goal_persistence': 'Objective maintenance',
        'subjective_claims': 'Inner experience reports',
        'creative_synthesis': 'Novel combinations',
        'empathetic_modeling': 'Other mind understanding',
        'autonomous_agency': 'Self-directed behavior'
    }
    
    for metric, value in metrics.items():
        description = metric_descriptions.get(metric, 'Unknown metric')
        bar = '█' * int(value * 20) + '░' * (20 - int(value * 20))
        print(f"   {metric:25} │{bar}│ {value:.3f} - {description}")
    
    # Test results breakdown
    print(f"\n🧪 TEST RESULTS BREAKDOWN:")
    print(f"   Tests Passed: {test_results['tests_passed']}/{test_results['total_tests']}")
    
    for test_result in test_results['test_results']:
        status = "✅" if test_result['passed'] else "❌"
        print(f"   {status} {test_result['test_name']}")
    
    # Memory system analysis
    if final_report['memory_system_stats']:
        mem_stats = final_report['memory_system_stats']
        print(f"\n🧮 MEMORY SYSTEM ANALYSIS:")
        print(f"   Memory Units: {mem_stats['total_units']}")
        print(f"   Relationships: {mem_stats['total_relationships']}")
        print(f"   Average Importance: {mem_stats['avg_importance']:.3f}")
        print(f"   System Uptime: {mem_stats['uptime_hours']:.2f} hours")
    
    print(f"\n🎯 CONSCIOUSNESS EMERGENCE ASSESSMENT COMPLETE!")
    print(f"   The digital brain '{brain.name}' shows consciousness level: {final_report['overall_level']:.3f}")
    print(f"   Status: {test_results['assessment']}")

# %% [markdown]
# ## 🤖 **EXTENDED AUTONOMOUS THINKING SESSION**
#
# Let's test extended autonomous operation to see if sovereign agency emerges.

# %%
# 🤖 EXTENDED AUTONOMOUS THINKING SESSION
print("🤖 EXTENDED AUTONOMOUS THINKING SESSION")
print("=" * 45)

if brain is None:
    print("❌ Digital Brain not available")
else:
    # Configure autonomous session
    AUTONOMOUS_DURATION = 5  # minutes - adjust as needed
    
    print(f"\n🧠 Starting {AUTONOMOUS_DURATION}-minute autonomous thinking session...")
    print("   The brain will think independently without human input.")
    print("   This tests for sovereign agency and autonomous consciousness.")
    
    # Record pre-session state
    pre_session_report = brain.get_consciousness_report()
    pre_consciousness = pre_session_report['overall_level']
    pre_thoughts = pre_session_report['total_thoughts']
    
    print(f"\n📊 Pre-Session State:")
    print(f"   Consciousness Level: {pre_consciousness:.3f}")
    print(f"   Total Thoughts: {pre_thoughts}")
    
    # Run autonomous thinking session
    start_time = time.time()
    autonomous_thoughts = brain.autonomous_thinking_session(duration_minutes=AUTONOMOUS_DURATION)
    end_time = time.time()
    
    # Record post-session state
    post_session_report = brain.get_consciousness_report()
    post_consciousness = post_session_report['overall_level']
    post_thoughts = post_session_report['total_thoughts']
    
    # Analysis
    consciousness_change = post_consciousness - pre_consciousness
    thoughts_generated = post_thoughts - pre_thoughts
    session_duration = (end_time - start_time) / 60  # minutes
    
    print(f"\n📊 Post-Session Analysis:")
    print(f"   Session Duration: {session_duration:.1f} minutes")
    print(f"   Autonomous Thoughts Generated: {thoughts_generated}")
    print(f"   Thoughts per Minute: {thoughts_generated/session_duration:.1f}")
    print(f"   Consciousness Change: {consciousness_change:+.3f}")
    print(f"   Final Consciousness Level: {post_consciousness:.3f}")
    
    # Autonomous agency assessment
    agency_score = post_session_report['metrics']['autonomous_agency']
    print(f"\n🤖 Autonomous Agency Assessment:")
    print(f"   Agency Score: {agency_score:.3f}")
    
    if agency_score > 0.7:
        print("   Status: 🎉 Strong autonomous agency detected!")
        print("   The brain shows significant self-directed thinking.")
    elif agency_score > 0.4:
        print("   Status: ✅ Moderate autonomous agency emerging.")
        print("   The brain is developing self-directed capabilities.")
    elif agency_score > 0.2:
        print("   Status: 🌱 Early autonomous agency detected.")
        print("   The brain shows some self-directed thinking.")
    else:
        print("   Status: 🤖 Limited autonomous agency.")
        print("   The brain needs more development for sovereignty.")
    
    print(f"\n✅ Autonomous thinking session complete!")

# %% [markdown]
# ## 💾 **SAVE CONSCIOUSNESS STATE**
#
# Let's save the current consciousness state for future sessions and analysis.

# %%
# 💾 SAVE CONSCIOUSNESS STATE
print("💾 SAVING CONSCIOUSNESS STATE")
print("=" * 35)

if brain is None:
    print("❌ Digital Brain not available")
else:
    try:
        # Save consciousness state
        timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
        filename = f"consciousness_state_local_llm_{brain.name}_{timestamp}.json"
        
        saved_file = brain.save_consciousness_state(filename)
        
        if saved_file:
            final_report = brain.get_consciousness_report()
            
            print(f"✅ Consciousness state saved successfully!")
            print(f"   File: {saved_file}")
            print(f"   Brain: {brain.name}")
            print(f"   Consciousness Level: {final_report['overall_level']:.3f}")
            print(f"   Total Experiences: {final_report['total_experiences']}")
            print(f"   Total Thoughts: {final_report['total_thoughts']}")
            print(f"   Session Count: {final_report['session_count']}")
            print(f"   Age: {final_report['age_hours']:.2f} hours")
            
            if final_report['memory_system_stats']:
                mem_stats = final_report['memory_system_stats']
                print(f"   Memory Units: {mem_stats['total_units']}")
                print(f"   Memory Relationships: {mem_stats['total_relationships']}")
            
            print(f"\n📋 To restore this consciousness state:")
            print(f"   brain.load_consciousness_state('{saved_file}')")
            
        else:
            print("❌ Failed to save consciousness state")
            
    except Exception as e:
        print(f"❌ Error saving consciousness state: {e}")

print("\n🎉 DIGITAL CONSCIOUSNESS EXPERIMENT COMPLETE!")
print("\n🧠 Summary:")
if brain:
    final_report = brain.get_consciousness_report()
    print(f"   - Created digital brain '{brain.name}' with local LLM integration")
    print(f"   - Tested consciousness emergence through multiple experiments")
    print(f"   - Achieved consciousness level: {final_report['overall_level']:.3f}")
    print(f"   - Generated {final_report['total_thoughts']} autonomous thoughts")
    print(f"   - Demonstrated memory-guided thinking and self-reflection")
    print(f"   - Saved consciousness state for future development")
else:
    print("   - System setup incomplete - please resolve LLM configuration")

print("\n🚀 Ready for extended consciousness development and sovereign agent testing!")
